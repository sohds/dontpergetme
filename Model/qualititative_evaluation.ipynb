# %% [markdown]
# ## 라이브러리 임포트

# %%
import pandas as pd
from collections import Counter
import ast
import re

# %% [markdown]
# ## 데이터 불러오기

# %%
recom = pd.read_csv('recommend_check.csv')
recom.head(2)
# Out:
#      city                                keyword  \
# 0  London  ['traditional', 'cultural', 'exotic']
# 1   Paris     ['lush', 'luxurious', 'exquisite']
#
#                                       recommendation
# 0  ['Pour Femme Dylan Blue Versace Versace', 'Le ...
# 1  ['M. Balode Florascent', 'Tobacco Pod For the ...

# %% [markdown]
# ## 향수가 대표하는 키워드 찾기
# - 임의로 향수 선정해 그 향수가 대표하는 키워드가 무엇일지 평가해보기
# - 향수가 포함되어있는 행을 찾고, 그 행에서 키워드를 뽑아 키워드가 몇 번 나왔는지 counts

# %%
def filter_perfume(df, name):
    escaped_name = re.escape(name)  # Escape the name to avoid regex issues
    return df[df['recommendation'].str.contains(escaped_name, na=False)]

# %%
def count_keyword(df):
    # Combine all keywords from the filtered data
    all_keywords = []
    for keywords in df['keyword']:
        # Convert the string representation of the list to an actual list
        keyword_list = ast.literal_eval(keywords)
        all_keywords.extend(keyword_list)

    # Count the occurrences of each keyword
    keyword_counts = Counter(all_keywords)

    # Convert the counter to a DataFrame for easier display
    keyword_counts_df = pd.DataFrame(keyword_counts.items(), columns=['Keyword', 'Count'])

    # Sort the DataFrame by count in descending order
    keyword_counts_df = keyword_counts_df.sort_values(by='Count', ascending=False).reset_index(drop=True)
    
    return keyword_counts_df

# %% [markdown]
# ### Maison Margiela
# #### Keyword Frequent Counts
# - flower market: active, lush
# - from the garden: unique, relaxing
# - flying: luxurious, tranquil, relaxing, romantic

# %%
# Flower Market Maison Martin Margiela

flowermarket = filter_perfume(recom, 'Flower Market Maison Martin Margiela')
flowermarket
# Out:
#               city                              keyword  \
# 62  Rio de Janeiro   ['cultural', 'peaceful', 'active']
# 75     Mexico City       ['lush', 'relaxing', 'active']
# 77            Lyon    ['exquisite', 'unique', 'active']
# 79       Rotterdam  ['bustling', 'lush', 'picturesque']
# 98          Bilbao  ['adventurous', 'exotic', 'active']
#
#                                        recommendation
# 62  ['Pour Homme Versace Versace', 'Idôle  Lancome...
# 75  ['Pour Homme Versace Versace', 'Flower Market ...
# 77  ['Pour Homme Versace Versace', 'Idôle  Lancome...
# 79  ['Forever and Ever Dior Dior', 'Wild Bluebell ...
# 98  ['Pour Homme Versace Versace', 'Flower Market ...

# %%
flowermarket_keywords = count_keyword(flowermarket)
flowermarket_keywords
# Out:
#         Keyword  Count
# 0        active      4
# 1          lush      2
# 2      cultural      1
# 3      peaceful      1
# 4      relaxing      1
# 5     exquisite      1
# 6        unique      1
# 7      bustling      1
# 8   picturesque      1
# 9   adventurous      1
# 10       exotic      1

# %%
# From The Garden Maison Martin Margiela

fromthegarden = filter_perfume(recom, 'From the Garden Maison Martin Margiela')
fromthegarden
# Out:
#             city                                   keyword  \
# 27        Riyadh         ['unique', 'tranquil', 'vibrant']
# 29        Munich          ['relaxing', 'unique', 'trendy']
# 39        Warsaw         ['active', 'luxurious', 'unique']
# 67  Philadelphia  ['relaxing', 'exquisite', 'traditional']
# 82      Valencia          ['lush', 'romantic', 'cultural']
# 96    Gothenburg        ['relaxing', 'peaceful', 'unique']
#
#                                        recommendation
# 27  ['4711 Acqua Colonia Intense Pure Breeze Of Hi...
# 29  ['4711 Acqua Colonia Intense Pure Breeze Of Hi...
# 39  ['Rhubarb and Citrus Cologne 4160 Tuesdays', '...
# 67  ['Baiser Vole  Cartier', 'La Tulipe  Byredo', ...
# 82  ['Grand Soir  Maison Francis Kurkdjian', 'Mole...
# 96  ['Baiser Vole  Cartier', 'Les Exclusifs de  Be...

# %%
fromthegarden_keywords = count_keyword(fromthegarden)
fromthegarden_keywords
# Out:
#         Keyword  Count
# 0        unique      4
# 1      relaxing      3
# 2      tranquil      1
# 3       vibrant      1
# 4        trendy      1
# 5        active      1
# 6     luxurious      1
# 7     exquisite      1
# 8   traditional      1
# 9          lush      1
# 10     romantic      1
# 11     cultural      1
# 12     peaceful      1

# %%
# Flying  Maison Martin Margiela

flying = filter_perfume(recom, 'Flying  Maison Martin Margiela')
flying
# Out:
#          city                                  keyword  \
# 1       Paris       ['lush', 'luxurious', 'exquisite']
# 3       Tokyo      ['exotic', 'luxurious', 'tranquil']
# 44      Osaka  ['picturesque', 'tranquil', 'relaxing']
# 87      Leeds       ['romantic', 'relaxing', 'unique']
# 92    Calgary  ['romantic', 'adventurous', 'peaceful']
# 99  Baltimore      ['active', 'trendy', 'traditional']
#
#                                        recommendation
# 1   ['M. Balode Florascent', 'Tobacco Pod For the ...
# 3   ['Sakura Dior', 'Flying  Maison Martin Margiel...
# 44  ['Tobacco Pod For the Scent of It', 'Sakura Di...
# 87  ['Flying  Maison Martin Margiela', 'Le Parfum ...
# 92  ['Fresia Santa Maria Novella', "L'Instant de  ...
# 99  ['Flying  Maison Martin Margiela', 'True Leath...

# %%
flying_keywords = count_keyword(flying)
flying_keywords
# Out:
#         Keyword  Count
# 0     luxurious      2
# 1      tranquil      2
# 2      relaxing      2
# 3      romantic      2
# 4          lush      1
# 5     exquisite      1
# 6        exotic      1
# 7   picturesque      1
# 8        unique      1
# 9   adventurous      1
# 10     peaceful      1
# 11       active      1
# 12       trendy      1
# 13  traditional      1

# %% [markdown]
# ### Jo Malone
# - Wild Bluebell: Active, Picturesque, Lush
# - Red Rose Cologne: Luxurious, Grand

# %%
# Wild Bluebell  Jo Malone London

wildbluebell = filter_perfume(recom, 'Wild Bluebell')
wildbluebell
# Out:
#            city                                keyword  \
# 8     Amsterdam  ['relaxing', 'active', 'picturesque']
# 43         Oslo         ['active', 'peaceful', 'lush']
# 79    Rotterdam    ['bustling', 'lush', 'picturesque']
# 85  New Orleans          ['active', 'exotic', 'grand']
#
#                                        recommendation
# 8   ['Tobacco Pod For the Scent of It', 'Forever a...
# 43  ['Forever and Ever Dior Dior', 'Wild Bluebell ...
# 79  ['Forever and Ever Dior Dior', 'Wild Bluebell ...
# 85  ['Tosca Tosca', 'Alahine  Teo Cabanel', 'Acqua...

# %%
wildbluebell_keywords = count_keyword(wildbluebell)
wildbluebell_keywords
# Out:
#        Keyword  Count
# 0       active      3
# 1  picturesque      2
# 2         lush      2
# 3     relaxing      1
# 4     peaceful      1
# 5     bustling      1
# 6       exotic      1
# 7        grand      1

# %%
# Red Roses Cologne (2023) Jo Malone London

redrosecologne = filter_perfume(recom, 'Red Roses Cologne')
redrosecologne
# Out:
#           city                               keyword  \
# 58   Las Vegas   ['bustling', 'active', 'luxurious']
# 69      Denver    ['grand', 'luxurious', 'peaceful']
# 71  Manchester  ['cultural', 'grand', 'picturesque']
#
#                                        recommendation
# 58  ['Meliora  Parfums de Marly', 'ADAM AAP PERFUM...
# 69  ['ADAM AAP PERFUMES', 'Red Roses Cologne (2023...
# 71  ['ADAM AAP PERFUMES', 'Her Intense Burberry Bu...

# %%
redrosecologne_keywords = count_keyword(redrosecologne)
redrosecologne_keywords
# Out:
#        Keyword  Count
# 0    luxurious      2
# 1        grand      2
# 2     bustling      1
# 3       active      1
# 4     peaceful      1
# 5     cultural      1
# 6  picturesque      1

# %% [markdown]
# ### Dior
# - Miss Dior Rose N'Roses Dior: Exquisite, Pircturesque

# %%
# Miss Dior Rose N'Roses Dior

rosenroses = filter_perfume(recom, "Miss Dior Rose N'Roses Dior")
rosenroses
# Out:
#          city                                      keyword  \
# 10       Rome       ['adventurous', 'active', 'exquisite']
# 23     Boston  ['exquisite', 'picturesque', 'traditional']
# 30  Melbourne      ['picturesque', 'peaceful', 'cultural']
#
#                                        recommendation
# 10  ['Grand Soir  Maison Francis Kurkdjian', 'Citr...
# 23  ['Citronnade Adopt Parfums', 'Garden Roses Bur...
# 30  ['Citronnade Adopt Parfums', 'Uomo  Signature ...

# %%
rosenroses_keywords = count_keyword(rosenroses)
rosenroses_keywords
# Out:
#        Keyword  Count
# 0    exquisite      2
# 1  picturesque      2
# 2  adventurous      1
# 3       active      1
# 4  traditional      1
# 5     peaceful      1
# 6     cultural      1

# %% [markdown]
# ### Chloe
# - Chloe Eau de Parfum  Chloé: Active, Tranquil

# %%
# Chloe Eau de Parfum  Chloé

chloe = filter_perfume(recom, "Chloe Eau de Parfum  Chloé")
chloe
# Out:
#         city                                keyword  \
# 37  San Jose     ['active', 'tranquil', 'bustling']
# 64   Atlanta  ['active', 'tranquil', 'traditional']
#
#                                        recommendation
# 37  ['Le Jardin de Monsieur Li  Hermès', 'Sakura D...
# 64  ['Addict To Life Dior', '4711 Acqua Colonia In...

# %% [markdown]
# ### Santa Maria Novella
# - Fresia: Active, Bustling

# %%
# Fresia Santa Maria Novella
fresia = filter_perfume(recom, "Fresia Santa Maria Novella")
fresia
# Out:
#               city                                  keyword  \
# 54    Buenos Aires    ['relaxing', 'bustling', 'exquisite']
# 62  Rio de Janeiro       ['cultural', 'peaceful', 'active']
# 75     Mexico City           ['lush', 'relaxing', 'active']
# 77            Lyon        ['exquisite', 'unique', 'active']
# 90         Cologne         ['bustling', 'active', 'trendy']
# 92         Calgary  ['romantic', 'adventurous', 'peaceful']
# 94      Dusseldorf         ['bustling', 'active', 'trendy']
# 98          Bilbao      ['adventurous', 'exotic', 'active']
#
#                                        recommendation
# 54  ['Hypnôse  Lancome', 'Pour Homme Versace Versa...
# 62  ['Pour Homme Versace Versace', 'Idôle  Lancome...
# 75  ['Pour Homme Versace Versace', 'Flower Market ...
# 77  ['Pour Homme Versace Versace', 'Idôle  Lancome...
# 90  ['Fresia Santa Maria Novella', 'Rhubarb and Ci...
# 92  ['Fresia Santa Maria Novella', "L'Instant de  ...
# 94  ['Fresia Santa Maria Novella', 'True Leather F...
# 98  ['Pour Homme Versace Versace', 'Flower Market ...

# %%
fresia_keywords = count_keyword(fresia)
fresia_keywords
# Out:
#         Keyword  Count
# 0        active      6
# 1      bustling      3
# 2      relaxing      2
# 3     exquisite      2
# 4      peaceful      2
# 5        trendy      2
# 6   adventurous      2
# 7      cultural      1
# 8          lush      1
# 9        unique      1
# 10     romantic      1
# 11       exotic      1

# %% [markdown]
# ### Victoria Secret
# - Bombshell: Relaxing

# %%
# Bombshell  Victoria's Secret
bombshell = filter_perfume(recom, "Bombshell  Victoria's Secret")
bombshell
# Out:
#         city                              keyword  \
# 2   New York  ['luxurious', 'relaxing', 'exotic']
# 15   Chicago   ['trendy', 'relaxing', 'peaceful']
#
#                                        recommendation
# 2   ['OR/18 A. N. OTHER', 'Garden Roses Burberry',...
# 15  ["Bombshell  Victoria's Secret", 'Mukhallat  M...

# %%
bombshell_keywords = count_keyword(bombshell)
bombshell_keywords
# Out:
#      Keyword  Count
# 0   relaxing      2
# 1  luxurious      1
# 2     exotic      1
# 3     trendy      1
# 4   peaceful      1

# %% [markdown]
# ### Guerlain
# - L'Instant de  pour Homme Guerlain Guerlain: Peaceful, Cultural

# %%
# L'Instant de  pour Homme Guerlain Guerlain
guerlain = filter_perfume(recom, "L'Instant de  pour Homme Guerlain Guerlain")
guerlain
# Out:
#            city                                   keyword  \
# 14  Los Angeles  ['luxurious', 'traditional', 'cultural']
# 19       Dublin           ['trendy', 'romantic', 'grand']
# 22      Toronto     ['exotic', 'peaceful', 'picturesque']
# 24    Abu Dhabi       ['peaceful', 'relaxing', 'vibrant']
# 25     Budapest     ['peaceful', 'active', 'adventurous']
# 42       Austin         ['cultural', 'peaceful', 'grand']
# 49    Vancouver          ['lush', 'romantic', 'peaceful']
# 50    San Diego      ['peaceful', 'cultural', 'bustling']
# 51      Orlando   ['picturesque', 'cultural', 'relaxing']
# 52     Helsinki       ['cultural', 'traditional', 'lush']
# 63     Auckland          ['romantic', 'lush', 'peaceful']
# 74  Minneapolis        ['trendy', 'cultural', 'peaceful']
# 83     Santiago     ['tranquil', 'luxurious', 'peaceful']
# 89       Ottawa   ['bustling', 'peaceful', 'adventurous']
# 92      Calgary   ['romantic', 'adventurous', 'peaceful']
#
#                                        recommendation
# 14  ['A La Rose Maison Francis Kurkdjian', 'Panama...
# 19  ['Rhubarb and Citrus Cologne 4160 Tuesdays', '...
# 22  ['Le Parfum Lalique Lalique', "L'Instant de  p...
# 24  ["L'Instant de  pour Homme Guerlain Guerlain",...
# 25  ["L'Instant de  pour Homme Guerlain Guerlain",...
# 42  ['Eros Flame  Versace', 'Bourmunque AK France'...
# 49  ['4711 Acqua Colonia Intense Pure Breeze Of Hi...
# 50  ['Fille en Aiguilles  Serge Lutens', 'Grand So...
# 51  ['Cedre Royal Acqua Reale', 'M7 Fresh Yves Sai...
# 52  ['Eudora H Energy Eudora', 'Acqua di Giò Profu...
# 63  ['M. Balode Florascent', "L'Instant de  pour H...
# 74  ['Urban Safari Man Alviero Martini', 'Olympéa ...
# 83  ['4711 Acqua Colonia Intense Pure Breeze Of Hi...
# 89  ['La Tulipe  Byredo', "Traversee du Bosphore L...
# 92  ['Fresia Santa Maria Novella', "L'Instant de  ...

# %%
guerlain_keywords = count_keyword(guerlain)
guerlain_keywords
# Out:
#         Keyword  Count
# 0      peaceful     11
# 1      cultural      6
# 2      romantic      4
# 3   adventurous      3
# 4          lush      3
# 5     luxurious      2
# 6   traditional      2
# 7        trendy      2
# 8         grand      2
# 9   picturesque      2
# 10     relaxing      2
# 11     bustling      2
# 12       exotic      1
# 13      vibrant      1
# 14       active      1
# 15     tranquil      1

# %% [markdown]
# ### Maison Francis Kurkdjian
# - Grand Soir: Active, Bustling

# %%
# Grand Soir  Maison Francis Kurkdjian
grandsoir = filter_perfume(recom, "Grand Soir  Maison Francis Kurkdjian")
grandsoir
# Out:
#          city                                 keyword  \
# 10       Rome  ['adventurous', 'active', 'exquisite']
# 12     Madrid      ['romantic', 'bustling', 'active']
# 38    Bangkok      ['bustling', 'active', 'tranquil']
# 50  San Diego    ['peaceful', 'cultural', 'bustling']
# 82   Valencia        ['lush', 'romantic', 'cultural']
#
#                                        recommendation
# 10  ['Grand Soir  Maison Francis Kurkdjian', 'Citr...
# 12  ['Grand Soir  Maison Francis Kurkdjian', 'Hypn...
# 38  ['Mukhallat Thai-Zone Abdul Karim Al Faransi',...
# 50  ['Fille en Aiguilles  Serge Lutens', 'Grand So...
# 82  ['Grand Soir  Maison Francis Kurkdjian', 'Mole...

# %%
grandsoir_keywords = count_keyword(grandsoir)
grandsoir_keywords
# Out:
#        Keyword  Count
# 0       active      3
# 1     bustling      3
# 2     romantic      2
# 3     cultural      2
# 4  adventurous      1
# 5    exquisite      1
# 6     tranquil      1
# 7     peaceful      1
# 8         lush      1

# %% [markdown]
# ## 지역 특성이 잘 보이는 향수
# - 지역을 임의적으로 뽑아 어떤 향수들이 뽑히는지 경향성 보기

# %%
def getcity(df, name):
    return df[df['city'].str.contains(name)]

# %%
def clean_data(cell):
    # Remove square brackets, single quotes, and extra spaces from the cell content
    return str(cell).replace('[', '').replace(']', '')

# %%
def split_perfume(df):
    cleaned_df = recom.applymap(clean_data)
    split_columns = recom['recommendation'].str.split(',', expand=True)
    split_columns.columns = [f'perfume_{i+1}' for i in range(split_columns.shape[1])]

    perfume_split = cleaned_df.drop('recommendation', axis=1).join(split_columns)
    
    return perfume_split

# %%
perfume_split = split_perfume(recom)
# Out:
# C:\Users\sohtk\AppData\Local\Temp\ipykernel_10836\3352076714.py:2: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   cleaned_df = recom.applymap(clean_data)

# %%
perfume_split.head(2)
# Out:
#      city                              keyword  \
# 0  London  'traditional', 'cultural', 'exotic'
# 1   Paris     'lush', 'luxurious', 'exquisite'
#
#                                   perfume_1  \
# 0  ['Pour Femme Dylan Blue Versace Versace'
# 1                   ['M. Balode Florascent'
#
#                             perfume_2                          perfume_3  \
# 0         'Le Parfum Lalique Lalique'          "Charming Jasmine A'pieu"
# 1   'Tobacco Pod For the Scent of It'   'Flying  Maison Martin Margiela'
#
#                                            perfume_4  \
# 0                               'Concerto Fragonard'
# 1   '4711 Acqua Colonia Intense Pure Breeze Of Hi...
#
#                                   perfume_5
# 0   '4711 Remix Cologne Edition 2018 4711']
# 1      'Instinct After Dark David Beckham']

# %% [markdown]
# #### 커피 문화가 발달한 곳

# %%
vienna = getcity(perfume_split, 'Vienna')
seattle = getcity(perfume_split, 'Seattle')
bogota = getcity(perfume_split, 'Bogota')

# %%
vienna
# Out:
#       city                      keyword                    perfume_1  \
# 20  Vienna  'unique', 'trendy', 'grand'  ['Overture Incarna parfums'
#
#                    perfume_2                              perfume_3  \
# 20   'Intense Cafe  Montale'   'Hobby Chic 10th Avenue Karl Antony'
#
#                            perfume_4  \
# 20   'Very Coffee Fernanda | フェルナンダ'
#
#                                             perfume_5
# 20   'Boss The Scent Private Accord for Her   Hugo...

# %%
seattle
# Out:
#        city                             keyword  \
# 33  Seattle  'traditional', 'grand', 'peaceful'
#
#                                             perfume_1  \
# 33  ['4711 Acqua Colonia Intense Pure Breeze Of Hi...
#
#                            perfume_2                         perfume_3  \
# 33   'Very Coffee Fernanda | フェルナンダ'   'Caffè Latte Fernanda | フェルナンダ'
#
#                       perfume_4  \
# 33   'Valentino Uomo Valentino'
#
#                                             perfume_5
# 33   'Uomo  Signature  Salvatore Ferragamo Salvato...

# %%
bogota
# Out:
#       city                              keyword  \
# 80  Bogota  'exquisite', 'peaceful', 'tranquil'
#
#                          perfume_1                         perfume_2  \
# 80  ['Kenzo Amour Le Parfum Kenzo'   'Very Coffee Fernanda | フェルナンダ'
#
#                            perfume_3  \
# 80   'Caffè Latte Fernanda | フェルナンダ'
#
#                                             perfume_4  \
# 80   '4711 Acqua Colonia Intense Pure Breeze Of Hi...
#
#                                             perfume_5
# 80   'Uomo  Signature  Salvatore Ferragamo Salvato...

# %% [markdown]
# - Vienna
#     - 비엔나 커피와 같이, 지명이 들어간 커피가 있는 만큼 발달되어있는 커피 문화
# - Seattle
#     - 스타벅스 1호점이 있는만큼, 주민들의 높은 커피 문화
# - Bogota
#     - 콜롬비아, 원두 생산지

# %% [markdown]
# ### 일본
# * 일본의 유명한 꽃, 벚꽃(Sakura)은 꼭 하나씩 추천하고 있는 모습

# %%
tokyo = getcity(perfume_split, 'Tokyo')
sapporo = getcity(perfume_split, 'Sapporo')
nagoya = getcity(perfume_split, 'Nagoya')
osaka = getcity(perfume_split, 'Osaka')

# %%
tokyo
# Out:
#     city                            keyword       perfume_1  \
# 3  Tokyo  'exotic', 'luxurious', 'tranquil'  ['Sakura Dior'
#
#                            perfume_2  \
# 3   'Flying  Maison Martin Margiela'
#
#                                            perfume_3  \
# 3   '4711 Acqua Colonia Intense Pure Breeze Of Hi...
#
#                     perfume_4               perfume_5
# 3   "Charming Jasmine A'pieu"   'Concerto Fragonard']

# %%
sapporo
# Out:
#        city                           keyword       perfume_1  \
# 97  Sapporo  'bustling', 'active', 'relaxing'  ['Sakura Dior'
#
#                              perfume_2  \
# 97   'Tobacco Pod For the Scent of It'
#
#                                  perfume_3         perfume_4  \
# 97   'Sakura Eau de Parfum Acqua di Parma'   'Comète Chanel'
#
#                      perfume_5
# 97   'Eudora H Energy Eudora']

# %%
nagoya
# Out:
#       city                              keyword  \
# 93  Nagoya  'adventurous', 'active', 'tranquil'
#
#                          perfume_1       perfume_2  \
# 93  ['Kenzo Amour Le Parfum Kenzo'   'Sakura Dior'
#
#                      perfume_3       perfume_4                    perfume_5
# 93   'Faqat Lil Rijal  Rasasi'   'Love  Chloé'   'Plum Japonais  Tom Ford']

# %%
osaka
# Out:
#      city                                keyword  \
# 44  Osaka  'picturesque', 'tranquil', 'relaxing'
#
#                              perfume_1       perfume_2  \
# 44  ['Tobacco Pod For the Scent of It'   'Sakura Dior'
#
#                             perfume_3                             perfume_4  \
# 44   'Flying  Maison Martin Margiela'   'Instinct After Dark David Beckham'
#
#                            perfume_5
# 44   'Eau epicee  Jardin de France']

# %% [markdown]
# ### 해변이 있는 도시

# %%
kuwait = getcity(perfume_split, 'Kuwait')
miami = getcity(perfume_split, 'Miami')
sydney = getcity(perfume_split, 'Sydney')
singapore = getcity(perfume_split, 'Singapore')
busan = getcity(perfume_split, 'Busan')

# %%
kuwait
# Out:
#       city                          keyword                    perfume_1  \
# 57  Kuwait  'peaceful', 'exotic', 'vibrant'  ['Ocean  Demeter Fragrance'
#
#                           perfume_2             perfume_3  \
# 57   'Eau irisee  Jardin de France'   'Wandervogel 27 87'
#
#                              perfume_4                   perfume_5
# 57   'Tobacco Pod For the Scent of It'   'Kirke  Tiziana Terenzi']

# %%
miami
# Out:
#      city                        keyword                    perfume_1  \
# 53  Miami  'active', 'grand', 'cultural'  ['Ocean  Demeter Fragrance'
#
#                           perfume_2             perfume_3  \
# 53   'Eau irisee  Jardin de France'   'Wandervogel 27 87'
#
#                               perfume_4                   perfume_5
# 53   'Urban Safari Man Alviero Martini'   'Kirke  Tiziana Terenzi']

# %%
sydney
# Out:
#       city                                 keyword  \
# 34  Sydney  'luxurious', 'adventurous', 'cultural'
#
#                       perfume_1                        perfume_2  \
# 34  ['Ocean  Demeter Fragrance'   'Eau irisee  Jardin de France'
#
#                perfume_3                  perfume_4             perfume_5
# 34   'Wandervogel 27 87'   'Kirke  Tiziana Terenzi'   'Leather Oud Dior']

# %%
singapore
# Out:
#         city                              keyword  \
# 4  Singapore  'traditional', 'exotic', 'relaxing'
#
#                              perfume_1                    perfume_2  \
# 4  ['Levante Intense  Jo Milano Paris'   'Ocean  Demeter Fragrance'
#
#                          perfume_3                            perfume_4  \
# 4   'Armani Mania  Giorgio Armani'   'Fille en Aiguilles  Serge Lutens'
#
#                perfume_5
# 4   'Wandervogel 27 87']

# %%
busan
# Out:
#      city                             keyword  \
# 66  Busan  'peaceful', 'cultural', 'tranquil'
#
#                                             perfume_1  \
# 66  ['Light Blue Eau Intense Pour Homme  Dolce&Gab...
#
#                           perfume_2                           perfume_3  \
# 66   'Eau givree  Jardin de France'   'Freedom EDT Förster and Johnsen'
#
#           perfume_4                     perfume_5
# 66   'Hamaca 27 87'   'Ocean  Demeter Fragrance']

# %% [markdown]
# - Kuwait, Miami, Sydney, Singapore
#     - Ocean Demeter Fragrance
# - Busan
#     - Light Blue Eau Intense Pour Homme Dolce & Gabbana
